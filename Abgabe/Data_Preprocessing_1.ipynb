# %%
import pandas as pd

# %%
books = pd.read_csv('Downloads/books_1.Best_Books_Ever.csv')

# %%
books.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52478 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52478 non-null  object
#  1   title             52478 non-null  object
#  2   series            23470 non-null  object
#  3   author            52478 non-null  object
#  4   rating            52478 non-null  float64
#  5   description       51140 non-null  object
#  6   language          48672 non-null  object
#  7   isbn              52478 non-null  object
#  8   genres            52478 non-null  object
#  9   characters        52478 non-null  object
#  10  bookFormat        51005 non-null  object
#  11  edition           4955 non-null   object
#  12  pages             50131 non-null  object
#  13  publisher         48782 non-null  object
#  14  publishDate       51598 non-null  object
#  15  firstPublishDate  31152 non-null  object
# ...

# %%
books.isnull()
# Out:
#        bookId  title  series  author  rating  description  language   isbn  \
# 0       False  False   False   False   False        False     False  False
# 1       False  False   False   False   False        False     False  False
# 2       False  False   False   False   False        False     False  False
# 3       False  False    True   False   False        False     False  False
# 4       False  False   False   False   False        False     False  False
# ...       ...    ...     ...     ...     ...          ...       ...    ...
# 52473   False  False   False   False   False        False     False  False
# 52474   False  False   False   False   False        False     False  False
# 52475   False  False   False   False   False        False     False  False
# 52476   False  False    True   False   False        False     False  False
# 52477   False  False   False   False   False        False     False  False
#
# ...

# %%
books.isnull().sum()
# Out:
# bookId                  0
# title                   0
# series              29008
# author                  0
# rating                  0
# description          1338
# language             3806
# isbn                    0
# genres                  0
# characters              0
# bookFormat           1473
# edition             47523
# pages                2347
# publisher            3696
# publishDate           880
# firstPublishDate    21326
# awards                  0
# numRatings              0
# ratingsByStars          0
# likedPercent          622
# setting                 0
# coverImg              605
# bbeScore                0
# bbeVotes                0
# price               14365
# dtype: int64

# %%
books['title'].nunique()
# Out:
# 49927

# %%
books.size
# Out:
# 1311950

# %%
books.describe()
# Out:
#              rating    numRatings  likedPercent      bbeScore      bbeVotes
# count  52478.000000  5.247800e+04  51856.000000  5.247800e+04  52478.000000
# mean       4.021878  1.787865e+04     92.231545  1.984023e+03     22.529003
# std        0.367146  1.039448e+05      5.990689  3.515314e+04    369.158541
# min        0.000000  0.000000e+00      0.000000  0.000000e+00     -4.000000
# 25%        3.820000  3.410000e+02     90.000000  8.400000e+01      1.000000
# 50%        4.030000  2.307000e+03     94.000000  9.700000e+01      1.000000
# 75%        4.230000  9.380500e+03     96.000000  1.870000e+02      2.000000
# max        5.000000  7.048471e+06    100.000000  2.993816e+06  30516.000000

# %%
books.shape
# Out:
# (52478, 25)

# %%
books['language'].nunique()
# Out:
# 81

# %%
books['language'].unique()
# Out:
# array(['English', 'French', 'German', 'Persian', 'Arabic', nan, 'Spanish',
#        'Multiple languages', 'Portuguese', 'Indonesian', 'Turkish',
#        'Polish', 'Bulgarian', 'Tamil', 'Japanese', 'Romanian', 'Italian',
#        'French, Middle (ca.1400-1600)', 'Norwegian', 'Urdu', 'Dutch',
#        'Finnish', 'Marathi', 'Chinese', 'Swedish', 'Icelandic',
#        'Malayalam', 'Croatian', 'Estonian', 'Greek, Modern (1453-)',
#        'Russian', 'Kurdish', 'Danish', 'Hindi', 'Filipino; Pilipino',
#        'Serbian', 'Bengali', 'Malay', 'Catalan; Valencian', 'Czech',
#        'Vietnamese', 'Armenian', 'Georgian', 'Kannada', 'Korean',
#        'Nepali', 'Slovak', 'Telugu', 'Hungarian',
#        'English, Middle (1100-1500)', 'Azerbaijani', 'Farsi',
#        'Lithuanian', 'Ukrainian', 'Bokmål, Norwegian; Norwegian Bokmål',
#        'Iranian (Other)', 'Faroese', 'Basque', 'Macedonian', 'Maltese',
#        'Gujarati', 'Amharic', 'Aromanian; Arumanian; Macedo-Romanian',
# ...

# %%
books_eng = books[books['language'] == 'English']

# %%
books_eng = books['language'].value_counts()

# %%
books_eng
# Out:
# English                                  42661
# Arabic                                    1038
# Spanish                                    687
# French                                     579
# German                                     528
#                                          ...
# Aromanian; Arumanian; Macedo-Romanian        1
# Basque                                       1
# Faroese                                      1
# Iranian (Other)                              1
# Norwegian Nynorsk; Nynorsk, Norwegian        1
# Name: language, Length: 81, dtype: int64

# %%
middle = books[books['language']== 'English, Middle (1100-1500)']
print(middle['description'])
# Out:
# 13653    The most authentic edition of Chaucer's Comple...
# Name: description, dtype: object

# %%
books_fr = books[books['language'] == 'French']

# %%
books.isnull().sum()
# Out:
# bookId                  0
# title                   0
# series              29008
# author                  0
# rating                  0
# description          1338
# language             3806
# isbn                    0
# genres                  0
# characters              0
# bookFormat           1473
# edition             47523
# pages                2347
# publisher            3696
# publishDate           880
# firstPublishDate    21326
# awards                  0
# numRatings              0
# ratingsByStars          0
# likedPercent          622
# setting                 0
# coverImg              605
# bbeScore                0
# bbeVotes                0
# price               14365
# dtype: int64

# %%
books = books.drop(columns='price')
books.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# ...

# %%
books = books.drop(columns='pages', 'bbeScore', 'bbeVotes', 'coverImg', 'awards', 'publisher', 'publishDate', 'firstPublishDate', 'bookFormat', 'characters', 'isbn', 'series')
# Out:
#   Cell In [64], line 1
#     books = books.drop(columns='pages', 'bbeScore', 'bbeVotes', 'coverImg', 'awards', 'publisher', 'publishDate', 'firstPublishDate', 'bookFormat', 'characters', 'isbn', 'series')
#                                                                                                                                                                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
droplist = ['pages', 'bbeScore', 'bbeVotes', 'coverImg', 'awards', 'publisher', 'publishDate', 'firstPublishDate', 'bookFormat', 'characters', 'isbn', 'series']

# %%
books = books.drop(columns=droplist)

# %%
books.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description language  \
# ...

# %%
books = books.drop(columns='numRatings')

# %%
books = books.drop(columns='ratingsByStars')

# %%
books = books.drop(columns='likedPercent')

# %%
books.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description language  \
# ...

# %%
books = books.drop(columns='edition')

# %%
books.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description language  \
# ...

# %%
books = books.drop(columns='setting')

# %%
books = books.drop(columns='bookId')

# %%
books.head()
# Out:
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description language  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1  There is a door at the end of a silent corrido...  English
# 2  The unforgettable novel of a childhood in a sl...  English
# 3  Alternate cover edition of ISBN 9780679783268S...  English
# ...

# %%
books_copy = books.copy()

# %%
books_copy.dropna(subset = ['description'], inplace = True)

# %%
books_copy.isnull().sum()
# Out:
# title             0
# author            0
# rating            0
# description       0
# language       3473
# genres            0
# dtype: int64

# %%
books_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51140 entries, 0 to 52477
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        51140 non-null  object
#  1   author       51140 non-null  object
#  2   rating       51140 non-null  float64
#  3   description  51140 non-null  object
#  4   language     47667 non-null  object
#  5   genres       51140 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 2.7+ MB

# %%
books = books_copy

# %%
books['title'].nunique()
# Out:
# 48627

# %%
books['language'].nunique()
# Out:
# 78

# %%
books_eng
# Out:
# English                                  42661
# Arabic                                    1038
# Spanish                                    687
# French                                     579
# German                                     528
#                                          ...
# Aromanian; Arumanian; Macedo-Romanian        1
# Basque                                       1
# Faroese                                      1
# Iranian (Other)                              1
# Norwegian Nynorsk; Nynorsk, Norwegian        1
# Name: language, Length: 81, dtype: int64

# %%
books_eng = books[books['language'] == 'English']

# %%
books_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42151 entries, 0 to 52477
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        42151 non-null  object
#  1   author       42151 non-null  object
#  2   rating       42151 non-null  float64
#  3   description  42151 non-null  object
#  4   language     42151 non-null  object
#  5   genres       42151 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 2.3+ MB

# %%
display(books_eng)
# Out:
#                                            title  \
# 0                               The Hunger Games
# 1      Harry Potter and the Order of the Phoenix
# 2                          To Kill a Mockingbird
# 3                            Pride and Prejudice
# 4                                       Twilight
# ...                                          ...
# 52473                                  Fractured
# 52474                                    Anasazi
# 52475                                     Marked
# 52476                                Wayward Son
# 52477                        Daughter of Helaman
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# ...

# %%
books_eng = books[(books['language'] == 'English') | (books['language'] =='English, Middle (1100-1500)')]

# %%
books_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42152 entries, 0 to 52477
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        42152 non-null  object
#  1   author       42152 non-null  object
#  2   rating       42152 non-null  float64
#  3   description  42152 non-null  object
#  4   language     42152 non-null  object
#  5   genres       42152 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 2.3+ MB

# %%
lang = books[books['language'].isnull()]

# %%
lang
# Out:
#                                                    title  \
# 503                                 Mistress Suffragette
# 570                                   Invisible Monsters
# 645                                House of Sand and Fog
# 703                        The Awakening: Fate in Motion
# 751              One Fish, Two Fish, Red Fish, Blue Fish
# ...                                                  ...
# 52405                    Diana: A princess for the world
# 52411                                         Pixie Dust
# 52416                                        When I Fall
# 52429  Did God Really Command Genocide?: Coming to Te...
# 52464                                          Algedonic
#
#                                     author  rating  \
# 503        Diana Forbes (Goodreads Author)    4.34
# 570     Chuck Palahniuk (Goodreads Author)    3.98
# 645                        Andre Dubus III    3.85
# 703    Suzanne Boisvert (Goodreads Author)    4.31
# ...

# %%
dropl = []
x='the'
c = -1
for i in lang['description']:
    b = i
    c+=1
    if (x in b) == False:
        dropl.append(c)
        
    else:
        pass
    
print(dropl)
# Out:
# [180, 182, 192, 226, 228, 229, 232, 275, 296, 317, 330, 349, 387, 388, 389, 393, 415, 419, 427, 444, 452, 463, 476, 477, 487, 507, 511, 525, 541, 590, 592, 606, 627, 634, 642, 658, 666, 694, 707, 714, 753, 759, 766, 767, 799, 816, 824, 844, 905, 935, 945, 959, 964, 979, 983, 1022, 1049, 1052, 1078, 1097, 1108, 1126, 1133, 1135, 1145, 1150, 1171, 1176, 1193, 1224, 1256, 1258, 1261, 1262, 1268, 1292, 1300, 1315, 1344, 1345, 1351, 1353, 1369, 1388, 1407, 1436, 1438, 1447, 1452, 1491, 1501, 1507, 1512, 1533, 1537, 1542, 1555, 1557, 1575, 1589, 1611, 1616, 1619, 1626, 1627, 1631, 1637, 1648, 1654, 1659, 1664, 1668, 1670, 1680, 1687, 1710, 1713, 1722, 1724, 1749, 1757, 1758, 1772, 1778, 1794, 1798, 1812, 1813, 1814, 1817, 1818, 1826, 1827, 1840, 1842, 1848, 1884, 1900, 1903, 1904, 1906, 1910, 1928, 1930, 1931, 1933, 1936, 1939, 1947, 1994, 1998, 2003, 2005, 2015, 2023, 2026, 2038, 2065, 2071, 2078, 2100, 2105, 2121, 2127, 2128, 2143, 2156, 2158, 2161, 2176, 2186, 2193, 2198, 2209, 2212, 22
# ...

# %%
lang.drop(lang.index[dropl], inplace=True)
# Out:
# C:\Users\Line\AppData\Local\Temp\ipykernel_15420\166108544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lang.drop(lang.index[dropl], inplace=True)

# %%
lang.isnull().sum()
# Out:
# title             0
# author            0
# rating            0
# description       0
# language       3174
# genres            0
# dtype: int64

# %%
books_eng = books_eng.append(lang)
# Out:
# C:\Users\Line\AppData\Local\Temp\ipykernel_15420\3797776524.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   books_eng = books_eng.append(lang)

# %%
books_eng.isnull().sum()
# Out:
# title             0
# author            0
# rating            0
# description       0
# language       3174
# genres            0
# dtype: int64

# %%
books_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45326 entries, 0 to 52464
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        45326 non-null  object
#  1   author       45326 non-null  object
#  2   rating       45326 non-null  float64
#  3   description  45326 non-null  object
#  4   language     42152 non-null  object
#  5   genres       45326 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 2.4+ MB

# %%
books_eng.to_csv('Documents/leuphana/3/neural_networks/project/clean_data_nn.csv', index=False)

# %%
books_eng['rating'].min()
# Out:
# 0.0

# %%
books_eng['rating'].max()
# Out:
# 5.0

# %%
books_eng[books_eng['rating'] < 3]
# Out:
#                                                    title  \
# 3938                            How to Be a Perfect Girl
# 5752                                      Revealing Eden
# 7574                                               Pygmy
# 9100                                                Lost
# 11651                                    The Almost Moon
# ...                                                  ...
# 38988  Imp Empress: Falling in Love with Dragons: Aar...
# 45794            Running Shoes (The Shades of Northwood)
# 46754                                          L'an 2440
# 51039                        Quartet for the End of Time
# 51200                              Waiting For Kate Bush
#
#                                                   author  rating  \
# 3938                    Mary Williams (Goodreads Author)    2.88
# 5752                    Victoria Foyt (Goodreads Author)    1.99
# 7574                  Chuck Palahniuk (Goodreads Author)    2.97
# ...
